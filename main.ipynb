# %%
import numpy as np
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.stem import PorterStemmer
from pypdf import PdfReader

# %%
book=PdfReader('book1.pdf')

# %%
text=''
for i in range(3,len(book.pages)):
    page=book.pages[i]
    text+=page.extract_text()
print(len(text))
# Out:
# 46231

# %%
def preprocess_text(text):
    swords=set(nltk.corpus.stopwords.words('english'))
    stemmer=PorterStemmer()
    sentences=sent_tokenize(text)
    preprocess_sent=[]
    for sentence in sentences:
        words=word_tokenize(sentence)
        words=[stemmer.stem(word) for word in words if word.isalnum() and word not in swords]
        preprocess_sent.append(' '.join(words))
    return preprocess_sent

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def compute_tfidf(sentences):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(sentences)
    return tfidf_matrix

def score_sentences(tfidf_matrix):
    sentence_scores = tfidf_matrix.sum(axis=1)
    return sentence_scores

# %%
def generate_summary(text, top_n=5):
    preprocessed_sentences = preprocess_text(text)
    tfidf_matrix = compute_tfidf(preprocessed_sentences)
    sentence_scores = score_sentences(tfidf_matrix)
    
    ranked_sentences = [sent for _, sent in sorted(zip(sentence_scores, sent_tokenize(text)), reverse=True)]
    summary = ' '.join(ranked_sentences[:top_n])
    
    return summary

# %%
summary=generate_summary(text,5)
print(summary)
# Out:
# ['chapter', 't', 'sherlock', 'holm', 'alway', 'woman']
# ['i', 'seldom', 'heard', 'tion', 'name']
# ['in', 'eye', 'eclips', 'predomin', 'whole', 'sex']
# ['it', 'felt', 'emot', 'akin', 'love', 'iren', 'adler']
# ['all', 'emot', 'one', 'particularli', 'abhorr', 'cold', 'precis', 'admir', 'balanc', 'mind']
# ['he', 'i', 'take', 'perfect', 'reason', 'observ', 'machin', 'world', 'seen', 'lover', 'would', 'place', 'fals', 'posit']
# ['he', 'never', 'spoke', 'softer', 'passion', 'save', 'gibe', 'sneer']
# ['they', 'admir', 'thing', 'draw', 'veil', 'men', 'motiv', 'action']
# ['but', 'train', 'reason', 'admit', 'intrus', 'delic', 'ﬁneli', 'adjust', 'tempera', 'introduc', 'distract', 'factor', 'might', 'throw', 'doubt', 'upon', 'mental', 'result']
# ['grit', 'sensit', 'instrument', 'crack', 'one', 'lens', 'would', 'disturb', 'strong', 'emot', 'natur']
# ['and', 'yet', 'one', 'woman', 'woman', 'late', 'iren', 'adler', 'dubiou', 'question', 'memori']
# ['i', 'seen', 'littl', 'holm', 'late']
# ['my', 'marriag', 'drift', 'us', 'away']
# ['my', 'complet', 'happi', 'interest', 'rise', 'around', 'man', 'ﬁrst', 'ﬁnd', 'master', 'establish', 'sufﬁcient', 'absorb', 'attent', 'holm', 'loath', 'everi', 'form', 'societi', 'whole', 'bohemian', 'soul', 'remain', 'lodg', 'baker', 'street', 'buri', 'among', 'old', 'book', 'altern', 'week', 'week', 'cocain', 'ambit', 'drowsi', 'drug', 'ﬁerc', 'energi', 'keen', 'natur']
# ['he', 'still', 'ever', 'deepli', 'attract', 'studi', 'crime', 'occupi', 'immens', 'faculti', 'extraordinari', 'power', 'observ', 'follow', 'clue', 'clear', 'mysteri', 'done', 'hopeless', 'ofﬁcial', 'polic']
# ['from', 'time', 'time', 'i', 'heard', 'vagu', 'account', 'do', 'summon', 'odessa', 'case', 'trepoff', 'murder', 'clear', 'singular', 'tragedi', 'atkinson', 'brother', 'trincomale', 'ﬁnalli', 'mission', 'accomplish', 'delic', 'success', 'reign', 'famili', 'holland']
# ['beyond', 'sign', 'activ', 'howev', 'i', 'mere', 'share', 'reader', 'daili', 'press', 'i', 'knew', 'littl', 'former', 'friend', 'companion']
# ['one', 'twentieth', 'march', 'return', 'journey', 'patient', 'i', 'return', 'civil', 'practic', 'way', 'led', 'baker', 'street']
# ['as', 'i', 'pass', 'door', 'must', 'alway', 'ate', 'mind', 'woo', 'dark', 'incid', 'studi', 'scarlet', 'i', 'seiz', 'keen', 'desir', 'see', 'holm', 'know', 'employ', 'extraordinari', 'power']
# ['hi', 'room', 'brilliantli', 'lit', 'even', 'i', 'look', 'i', 'saw', 'tall', 'spare', 'ﬁgure', 'pass', 'twice', 'dark', 'silhouett', 'blind']
# ['he', 'pace', 'room', 'swiftli', 'eagerli', 'head', 'sunk', 'upon', 'chest', 'hand', 'clasp', 'behind']
# ['to', 'knew', 'everi', 'mood', 'habit', 'attitud', 'manner', 'told', 'stori']
# ['he', 'work']
# ['he', 'risen', 'dream', 'hot', 'upon', 'scent', 'new', 'problem']
# ['i', 'rang', 'bell', 'shown', 'chamber', 'formerli', 'part']
# ['hi', 'manner', 'effus']
# ['it', 'seldom', 'glad', 'i', 'think', 'see']
# ['with', 'hardli', 'word', 'spoken', 'kindli', 'eye', 'wave', 'armchair', 'threw', 'across', 'case', 'cigar', 'cate', 'spirit', 'case', 'gasogen', 'corner']
# ['then', 'stood', 'ﬁre', 'look', 'singular', 'introspect', 'fashion']
# ['wedlock', 'suit', 'remark']
# ['i', 'think', 'son', 'put', 'seven', 'half', 'pound', 'sinc', 'i', 'saw', 'seven', 'i', 'answer']
# ['inde', 'i', 'thought', 'littl']
# ['just', 'triﬂe', 'i', 'fanci', 'watson']
# ['and', 'practic', 'i', 'observ']
# ['you', 'tell', 'intend', 'go', 'then', 'know', 'i', 'see', 'i', 'deduc']
# ['how', 'i', 'know', 'get', 'wet', 'late', 'clumsi', 'careless', 'servant', 'girl', 'my', 'dear', 'holm', 'said', 'i', 'much']
# ['you', 'would', 'certainli', 'burn', 'live', 'centuri', 'ago']
# ['it', 'true', 'i', 'countri', 'walk', 'thursday', 'came', 'home', 'dread', 'mess', 'i', 'chang', 'cloth', 'i', 'imagin', 'deduc']
# ['as', 'mari', 'jane', 'incorrig', 'wife', 'given', 'notic', 'i', 'fail', 'see', 'work', 'he', 'chuckl', 'rub', 'long', 'vou', 'hand', 'togeth']
# ['it', 'simplic', 'said', 'eye', 'tell', 'insid', 'left', 'shoe', 'ﬁrelight', 'strike', 'leather', 'score', 'six', 'almost', '3parallel', 'cut']
# ['obvious', 'caus', 'someon', 'carelessli', 'scrape', 'round', 'edg', 'sole', 'order', 'remov', 'crust', 'mud']
# ['henc', 'see', 'doubl', 'deduct', 'vile', 'weather', 'particularli', 'malign', 'specimen', 'london', 'slavey']
# ['as', 'practic', 'gentleman', 'walk', 'room', 'smell', 'iodoform', 'black', 'mark', 'nitrat', 'silver', 'upon', 'right', 'ger', 'bulg', 'right', 'side', 'show', 'secret', 'stethoscop', 'i', 'must', 'dull', 'inde', 'i', 'pronounc', 'activ', 'member', 'medic', 'i', 'could', 'help', 'laugh', 'eas', 'explain', 'process', 'deduct']
# ['when', 'i', 'hear', 'give', 'reason', 'i', 'remark', 'thing', 'alway', 'appear', 'ridicul', 'simpl', 'i', 'could', 'easili', 'though', 'success', 'instanc', 'reason', 'i', 'bafﬂ', 'explain', 'process']
# ['and', 'yet', 'i', 'believ', 'eye', 'good', 'quit', 'answer', 'light', 'cigarett', 'throw', 'armchair']
# ['you', 'see', 'observ']
# ['the', 'distinct', 'clear']
# ['for', 'exampl', 'frequent', 'seen', 'step', 'lead', 'hall', 'how', 'often', 'well', 'hundr', 'then', 'mani', 'how', 'mani']
# ['i', 'quit']
# ['you', 'observ']
# ['and', 'yet', 'seen']
# ['that', 'point']
# ['now', 'i', 'know', 'seventeen', 'step', 'i', 'seen', 'observ']
# ['sinc', 'interest', 'littl', 'problem', 'sinc', 'good', 'enough', 'chronicl', 'one', 'two', 'triﬂe', 'experi', 'may', 'interest', 'he', 'threw', 'sheet', 'thick', 'lie', 'open', 'upon', 'tabl']
# ['it', 'came', 'last', 'post', 'said']
# ['read', 'the', 'note', 'undat', 'without', 'either', 'ture', 'address']
# ['there', 'call', 'upon', 'quarter', 'eight', 'clock', 'said', 'gentleman', 'desir', 'consult', 'upon', 'matter', 'deepest', 'ment']
# ['your', 'recent', 'servic', 'one', 'royal', 'hous', 'europ', 'shown', 'one', 'may', 'safe', 'trust', 'matter', 'tanc', 'hardli', 'exagger']
# ['thi', 'account', 'quarter', 'receiv']
# ['be', 'chamber', 'hour', 'take', 'amiss', 'visitor', 'wear', 'thi', 'inde', 'mysteri', 'i', 'remark']
# ['what', 'imagin', 'mean', 'i', 'data', 'yet']
# ['it', 'capit', 'mistak', 'oriz', 'one', 'data']
# ['insens', 'one', 'begin', 'twist', 'fact', 'suit', 'theori', 'instead', 'theori', 'suit', 'fact']
# ['but', 'note']
# ['what', 'deduc', 'i', 'care', 'examin', 'write', 'paper', 'upon', 'written']
# ['the', 'man', 'wrote', 'presum', 'well', 'i', 'remark', 'endeavour', 'imit', 'panion', 'process']
# ['such', 'paper', 'could', 'bought', 'half', 'crown', 'packet']
# ['it', 'peculiarli', 'strong', 'word', 'said', 'holm']
# ['it', 'english', 'paper']
# ['hold', 'i', 'saw', 'larg', 'e', 'small', 'g', 'p', 'larg', 'g', 'small', 'woven', 'textur', 'paper']
# ['what', 'make', 'ask', 'holm']
# ['the', 'name', 'maker', 'doubt', 'gram', 'not']
# ['the', 'g', 'small', 'stand', 'gesellschaft', 'german', 'it', 'customari', 'contract', 'like', 'p', 'cours', 'stand', 'now', 'let', 'us', 'glanc', 'continent', 'he', 'took', 'heavi', 'brown', 'volum', 'shelv']
# ['eglow', 'egria']
# ['it', 'speak', 'bohemia', 'far', 'bad']
# ['remark', 'scene', 'death', 'wallenstein', 'numer', 'ha', 'ha', 'boy', 'make', 'hi', 'eye', 'sparkl', 'sent', 'great', 'blue', 'triumphant', 'cloud', 'cigarett']
# ['the', 'paper', 'made', 'bohemia', 'i', 'said']
# ['precis']
# ['and', 'man', 'wrote', 'note', 'german']
# ['do', 'note', 'peculiar', 'construct', 'thi', 'account', 'quarter', 'a', 'frenchman', 'russian', 'could', 'written']
# ['it', 'german', 'courteou', 'verb']
# ['it', 'remain', 'therefor', 'discov', 'want', 'german', 'write', 'upon', 'bohemian', 'paper', 'prefer', 'wear', 'mask', 'show', 'face']
# ['and', 'come', 'i', 'mistaken', 'resolv', '4a', 'spoke', 'sharp', 'sound', 'hors', 'hoof', 'grate', 'wheel', 'curb', 'follow', 'sharp', 'pull', 'bell']
# ['holm', 'whistl']
# ['a', 'pair', 'sound', 'said']
# ['ye', 'tinu', 'glanc', 'window']
# ['a', 'nice', 'littl', 'brougham', 'pair', 'beauti']
# ['a', 'hundr', 'ﬁfti', 'guinea', 'apiec']
# ['there', 'money', 'case', 'watson', 'noth', 'i', 'think', 'i', 'better', 'go', 'not', 'bit', 'doctor']
# ['stay']
# ['i', 'lost', 'without', 'boswel']
# ['and', 'promis', 'interest']
# ['it', 'would', 'piti', 'miss', 'but', 'never', 'mind']
# ['i', 'may', 'want', 'help', 'may']
# ['here', 'come']
# ['sit', 'armchair', 'doctor', 'give', 'us', 'best', 'a', 'slow', 'heavi', 'step', 'heard', 'upon', 'stair', 'passag', 'paus', 'ate', 'outsid', 'door']
# ['then', 'loud', 'authorit', 'tap']
# ['come', 'said', 'holm']
# ['a', 'man', 'enter', 'could', 'hardli', 'less', 'six', 'feet', 'six', 'inch', 'height', 'chest', 'limb', 'hercul']
# ['hi', 'dress', 'rich', 'rich', 'would', 'england', 'look', 'upon', 'akin', 'bad', 'tast']
# ['heavi', 'band', 'astrakhan', 'slash', 'across', 'sleev', 'front', 'coat', 'deep', 'blue', 'cloak', 'thrown', 'shoulder', 'line', 'silk', 'secur', 'neck', 'brooch', 'sist', 'singl', 'ﬂame', 'beryl']
# ['boot', 'extend', 'halfway', 'calv', 'trim', 'top', 'rich', 'brown', 'fur', 'complet', 'sion', 'barbar', 'opul', 'suggest', 'whole', 'appear']
# ['he', 'carri', 'hat', 'hand', 'wore', 'across', 'upper', 'part', 'face', 'extend', 'past', 'cheekbon', 'black', 'vizard', 'mask', 'appar', 'adjust', 'moment', 'hand', 'still', 'rais', 'enter']
# ['from', 'lower', 'part', 'face', 'appear', 'man', 'strong', 'charact', 'thick', 'hang', 'lip', 'long', 'straight', 'chin', 'suggest', 'resolut', 'push', 'length', 'obstinaci']
# ['you', 'note', 'ask', 'deep', 'harsh', 'voic', 'strongli', 'mark', 'german', 'accent']
# ['i', 'told', 'i', 'would', 'he', 'look', 'one', 'us', 'uncertain', 'address']
# ['pray', 'take', 'seat', 'said', 'holm']
# ['thi', 'friend', 'colleagu', 'watson', 'occasion', 'good', 'enough', 'help', 'case']
# ['whom', 'i', 'honour', 'address', 'you', 'may', 'address', 'count', 'von', 'kramm', 'bohemian', 'nobleman']
# ['i', 'understand', 'man', 'friend', 'man', 'honour', 'discret', 'i', 'may', 'trust', 'matter', 'extrem', 'import']
# ['if', 'i', 'much', 'prefer', 'cate', 'i', 'rose', 'go', 'holm', 'caught', 'wrist', 'push', 'back', 'chair']
# ['it', 'none', 'said']
# ['you', 'may', 'say', 'gentleman', 'anyth', 'may', 'say', 'the', 'count', 'shrug', 'broad', 'shoulder']
# ['then', 'i', 'must', 'begin', 'said', 'bind', 'lute', 'secreci', 'two', 'year', 'end', 'time', 'matter', 'import']
# ['at', 'present', 'much', 'say', 'weight', 'may', 'inﬂuenc', 'upon', 'european', 'i', 'promis', 'said', 'holm']
# ['and', 'you', 'excus', 'mask', 'continu', 'strang', 'visitor']
# ['the', 'august', 'person', 'employ', 'wish', 'agent', 'unknown', 'i', 'may', 'confess', 'titl', 'i', 'call', 'exactli', 'i', 'awar', 'said', 'holm', 'dryli']
# ['the', 'circumst', 'great', 'delicaci', 'eri', 'precaut', 'taken', 'quench', 'might', 'grow', 'immens', 'scandal', 'serious', 'promis', 'one', 'reign', 'famili', 'europ']
# ['to', 'speak', 'plainli', 'matter', 'implic', 'great', 'hous', 'ormstein', 'hereditari', 'king', 'i', 'also', 'awar', 'murmur', 'holm', 'settl', 'armchair', 'close', 'eye']
# ['our', 'visitor', 'glanc', 'appar', 'surpris', 'languid', 'loung', 'ﬁgure', 'man', 'doubt', 'depict', 'incis', 'reason', 'energet', 'agent', 'europ']
# ['holm', 'slowli', 'reopen', 'eye', 'look', 'impati', 'gigant', 'client']
# ['if', 'majesti', 'would', 'condescend', 'state', 'case', 'remark', 'i', 'better', 'abl', 'advis', 'the', 'man', 'sprang', 'chair', 'pace', 'room', 'uncontrol', 'agit']
# ['then', 'gestur', 'desper', 'tore', 'mask', 'face', 'hurl', 'upon', 'ground']
# ['you', 'right', 'cri', 'i', 'king']
# ['whi', 'i', 'tempt', 'conceal', '5', 'whi', 'inde', 'murmur', 'holm']
# ['your', 'majesti', 'spoken', 'i', 'awar', 'i', 'address', 'wilhelm', 'gottsreich', 'sigismond', 'von', 'ormstein', 'grand', 'duke', 'tari', 'king', 'but', 'understand', 'said', 'strang', 'visitor', 'sit', 'pass', 'hand', 'high', 'white', 'forehead', 'understand', 'i', 'accustom', 'busi', 'person']
# ['yet', 'matter', 'delic', 'i', 'could', 'conﬁd', 'agent', 'without', 'put', 'power']
# ['i', 'come', 'incognito', 'pragu', 'purpos', 'consult', 'then', 'pray', 'consult', 'said', 'holm', 'shut', 'eye']
# ['the', 'fact', 'brieﬂi', 'some', 'ﬁve', 'year', 'ago', 'lengthi', 'visit', 'warsaw', 'i', 'made', 'tanc', 'adventuress', 'iren', 'adler']
# ['the', 'name', 'doubt', 'familiar', 'kindli', 'look', 'index', 'doctor', 'mure', 'holm', 'without', 'open', 'eye']
# ['for', 'mani', 'year', 'adopt', 'system', 'docket', 'graph', 'concern', 'men', 'thing', 'difﬁcult', 'name', 'subject', 'person', 'could', 'furnish', 'inform']
# ['in', 'case', 'i', 'found', 'biographi', 'sandwich', 'hebrew', 'rabbi', 'written', 'monograph', 'upon', 'ﬁshe']
# ['let', 'see', 'said', 'holm']
# ['hum']
# ['born', 'new', 'jersey', 'year', '1858']
# []
# ['la', 'scala', 'hum']
# ['prima', 'donna', 'imperi', 'opera']
# ['retir', 'operat']
# ['live']
# ['your', 'majesti', 'i', 'understand', 'becam', 'entangl', 'young', 'person', 'wrote', 'compromis', 'letter', 'desir', 'get', 'letter', 'precis']
# ['but', 'wa', 'secret', 'marriag', 'no', 'legal', 'paper', 'certiﬁc', 'then', 'i', 'fail', 'follow', 'majesti']
# ['if', 'young', 'person', 'produc', 'letter', 'blackmail', 'purpos', 'prove', 'iti', 'there', 'pooh', 'pooh']
# ['my', 'privat', 'my', 'my', 'we', 'oh', 'dear']
# ['that', 'bad']
# ['your', 'majesti', 'inde', 'commit', 'i', 'you', 'compromis', 'i', 'crown', 'princ']
# ['i', 'young']
# ['i', 'thirti', 'it', 'must', 'we', 'tri', 'your', 'majesti', 'must', 'pay']
# ['it', 'must', 'she', 'stolen', 'five', 'attempt', 'made']
# ['twice', 'burglar', 'pay', 'ransack', 'hous']
# ['onc', 'divert', 'luggag', 'travel']
# ['twice', 'waylaid']
# ['there', 'no', 'sign', 'absolut', 'holm', 'laugh']
# ['it', 'quit', 'pretti', 'littl', 'lem', 'said']
# ['but', 'seriou', 'one', 'return', 'king', 'reproach']
# ['veri', 'inde']
# ['and', 'propos', 'photograph', 'to', 'ruin', 'but', 'i', 'so', 'i', 'to', 'clotild', 'lothman', 'von', 'second', 'daughter', 'king', 'scandinavia']
# ['you', 'may', 'know', 'strict', 'principl', 'famili']
# ['she', 'soul', 'delicaci']
# ['a', 'shadow', 'doubt', 'conduct', 'would', 'bring', 'matter', 'and', 'iren', 'adler', 'threaten', 'send', 'photograph']
# ['and']
# ['i', 'know']
# ['you', 'know', 'soul', 'steel']
# ['she', 'face', 'beauti', 'women', 'mind', 'resolut', 'men']
# ['rather', 'i', 'marri', 'anoth', 'woman', 'length', 'would', 'you', 'sure', 'sent', 'yet', 'i', '6', 'and', 'becaus', 'said', 'would', 'send', 'day', 'betroth', 'publicli', 'proclaim']
# ['that', 'next', 'oh', 'three', 'day', 'yet', 'said', 'holm', 'yawn']
# ['that', 'fortun', 'i', 'one', 'two', 'matter', 'import', 'look', 'present']
# ['your', 'majesti', 'cours', 'stay', 'london', 'present', 'certainli']
# ['you', 'ﬁnd', 'langham', 'name', 'count', 'von', 'then', 'i', 'shall', 'drop', 'line', 'let', 'know', 'pray']
# ['i', 'shall', 'then', 'money', 'you', 'cart', 'absolut', 'i', 'tell', 'i', 'would', 'give', 'one', 'provinc', 'kingdom', 'and', 'present', 'expens', 'the', 'king', 'took', 'heavi', 'chamoi', 'leather', 'bag', 'cloak', 'laid', 'tabl']
# ['there', 'three', 'hundr', 'pound', 'gold', 'seven', 'hundr', 'note', 'said']
# ['holm', 'scribbl', 'receipt', 'upon', 'sheet', 'hand']
# ['and', 'mademoisel', 'address', 'ask']
# ['is', 'brioni', 'lodg', 'serpentin', 'avenu', 'john', 'holm', 'took', 'note']
# ['one', 'question', 'said']
# ['wa', 'photograph', 'cabinet', 'it', 'then', 'majesti', 'i', 'trust', 'shall', 'soon', 'good', 'news']
# ['and', 'watson', 'ad', 'wheel', 'royal', 'brougham', 'roll', 'street']
# ['if', 'good', 'enough', 'call', 'afternoon', 'three', 'clock', 'i', 'like', 'chat', 'littl', 'matter', 'chapter', 'ii']
# ['at', 'three', 'clock', 'precis', 'i', 'baker', 'street', 'holm', 'yet', 'return']
# ['the', 'landladi', 'form', 'left', 'hous', 'shortli', 'eight', 'clock', 'morn']
# ['i', 'sat', 'besid', 'ﬁre', 'howev', 'intent', 'await', 'ever', 'long', 'might']
# ['i', 'alreadi', 'deepli', 'est', 'inquiri', 'though', 'surround', 'none', 'grim', 'strang', 'featur', 'associ', 'two', 'crime', 'i', 'alreadi', 'record', 'still', 'natur', 'case', 'exalt', 'station', 'client', 'gave', 'charact']
# ['deed', 'apart', 'natur', 'investig', 'friend', 'hand', 'someth', 'masterli', 'grasp', 'situat', 'keen', 'incis', 'reason', 'made', 'pleasur', 'studi', 'system', 'work', 'follow', 'quick', 'subtl', 'method', 'disentangl', 'ble', 'mysteri']
# ['so', 'accustom', 'i', 'invari', 'success', 'possibl', 'fail', 'ceas', 'enter', 'head']
# ['it', 'close', 'upon', 'four', 'door', 'open', 'groom', 'whisker', 'inﬂam', 'face', 'disreput', 'cloth', 'walk', 'room']
# ['accustom', 'i', 'friend', 'amaz', 'power', 'use', 'disguis', 'i', 'look', 'three', 'time', 'i', 'certain', 'inde']
# ['with', 'nod', 'vanish', 'bedroom', 'whenc', 'emerg', 'ﬁve', 'minut', 'suit', 'respect', 'old']
# ['put', 'hand', 'pocket', 'stretch', 'leg', 'front', 'ﬁre', 'laugh', 'heartili', 'minut']
# ['well', 'realli', 'cri', 'choke', 'laugh', 'oblig', 'lie', 'back', 'limp', 'helpless', 'chair']
# ['what', 'it', 'quit', 'funni']
# ['i', 'sure', 'could', 'never', 'guess', 'i', 'employ', 'morn', 'i', 'end', 'i', 'imagin']
# ['i', 'suppos', 'watch', 'habit', 'perhap', 'hous', 'miss', 'iren', '7', 'quit', 'sequel', 'rather', 'unusu']
# ['i', 'tell', 'howev']
# ['i', 'left', 'hous', 'littl', 'eight', 'clock', 'morn', 'charact', 'groom', 'work']
# ['there', 'wonder', 'sympathi', 'freemasonri', 'among', 'horsey', 'men']
# ['be', 'one', 'know', 'know']
# ['i', 'soon', 'found', 'brioni', 'lodg']
# ['it', 'bijou', 'villa', 'garden', 'back', 'built', 'front', 'right', 'road', 'two', 'stori']
# ['chubb', 'lock', 'door']
# ['larg', 'right', 'side', 'well', 'furnish', 'long', 'window', 'almost', 'ﬂoor', 'preposter', 'english', 'window', 'fasten', 'child', 'could', 'open']
# ['behind', 'noth', 'remark', 'save', 'passag', 'window', 'could', 'reach', 'top', 'hous']
# ['i', 'walk', 'round', 'examin', 'close', 'everi', 'point', 'view', 'without', 'note', 'anyth', 'els', 'interest']
# ['i', 'loung', 'street', 'found', 'i', 'expect', 'mew', 'lane', 'run', 'one', 'wall', 'garden']
# ['i', 'lent', 'ostler', 'hand', 'rub', 'hors', 'receiv', 'exchang', 'twopenc', 'glass', 'half', 'half', 'two', 'ﬁll', 'shag', 'tobacco', 'much', 'inform', 'i', 'could', 'desir', 'miss', 'adler', 'say', 'noth', 'half', 'dozen', 'peopl', 'neighbourhood', 'i', 'least', 'interest', 'whose', 'biographi', 'i', 'compel', 'listen', 'and', 'iren', 'adler', 'i', 'ask']
# ['oh', 'turn', 'men', 'head', 'part']
# ['she', 'daintiest', 'thing', 'bonnet', 'planet']
# ['so', 'say', 'man']
# ['she', 'live', 'quietli', 'sing', 'concert', 'drive', 'ﬁve', 'everi', 'day', 'return', 'seven', 'sharp', 'dinner']
# ['dom', 'goe', 'time', 'except', 'sing']
# ['ha', 'one', 'male', 'visitor', 'good', 'deal']
# ['he', 'dark', 'handsom', 'dash', 'never', 'call', 'less', 'day', 'often', 'twice']
# ['he', 'godfrey', 'norton', 'inner', 'templ']
# ['see', 'advantag', 'cabman', 'conﬁdant']
# ['they', 'driven', 'home', 'dozen', 'time', 'knew']
# ['when', 'i', 'listen', 'tell', 'i', 'began', 'walk', 'near', 'brioni', 'lodg', 'think', 'plan', 'campaign']
# ['thi', 'godfrey', 'norton', 'evid', 'import', 'factor', 'matter']
# ['he', 'lawyer']
# ['that', 'sound', 'omin']
# ['what', 'relat', 'object', 'repeat', 'visit']
# ['wa', 'client', 'friend', 'mistress']
# ['if', 'former', 'probabl', 'transfer', 'photograph', 'ing']
# ['if', 'latter', 'less', 'like']
# ['on', 'issu', 'question', 'depend', 'whether', 'i', 'continu', 'work', 'brioni', 'lodg', 'turn', 'attent', 'gentleman', 'chamber', 'templ']
# ['it', 'delic', 'point', 'widen', 'ﬁeld', 'inquiri']
# ['i', 'fear', 'i', 'bore', 'detail', 'i', 'let', 'see', 'littl', 'difﬁculti', 'understand', 'i', 'follow', 'close', 'i', 'answer']
# ['i', 'still', 'balanc', 'matter', 'mind', 'hansom', 'cab', 'drove', 'brioni', 'lodg', 'tleman', 'sprang']
# ['he', 'remark', 'handsom', 'man', 'dark', 'aquilin', 'man', 'i', 'heard']
# ['he', 'appear', 'great', 'hurri', 'shout', 'cabman', 'wait', 'brush', 'past', 'maid', 'open', 'door', 'air', 'man', 'thoroughli', 'home']
# ['he', 'hous', 'half', 'hour', 'i', 'could', 'catch', 'glimps', 'window', 'pace', 'talk', 'excitedli', 'wave', 'arm']
# ['of', 'i', 'could', 'see', 'noth']
# ['present', 'emerg', 'look', 'even', 'ﬂurri']
# ['as', 'step', 'cab', 'pull', 'gold', 'watch', 'pocket', 'look', 'earnestli', 'drive', 'like', 'devil', 'shout', 'ﬁrst', 'gross', 'hankey', 'regent', 'street', 'church', 'monica', 'edgewar', 'road']
# ['half', 'guinea', 'twenti', 'minut', 'away', 'went', 'i', 'wonder', 'whether', 'i', 'well', 'follow', 'lane', 'came', 'neat', 'littl', 'landau', 'coachman', 'coat', 'tie', 'ear', 'tag', 'har', 'stick', 'buckl']
# ['it', 'pull', 'shot', 'hall', 'door']
# ['i', 'caught', 'glimps', 'moment', 'love', 'woman', 'face', 'man', 'might', 'die']
# ['the', 'church', 'monica', 'john', 'cri', 'half', 'sovereign', 'reach', 'twenti', 'thi', 'quit', 'good', 'lose', 'watson']
# ['i', 'balanc', 'whether', 'i', 'run', 'whether', 'i', 'perch', 'behind', 'landau', 'cab', 'came', 'street']
# ['the', 'driver', 'look', 'twice', 'shabbi', 'fare', 'i', 'jump', 'could', 'ject']
# ['the', 'church', 'monica', 'said', 'i', 'half', 'sovereign', 'reach', 'twenti', 'it', 'minut', 'twelv', 'cours', 'clear', 'enough', 'wind']
# ['my', 'cabbi', 'drove', 'fast']
# ['i', 'think', 'i', 'ever', 'drove', 'faster', 'other', 'us']
# ['the', 'cab', 'landau', 'steam', 'hors', 'front', 'door', 'i', 'arriv']
# ['i', 'paid', 'man', 'hurri', 'church']
# ['there', 'soul', 'save', 'two', 'i', 'follow', 'plice', 'clergyman', 'seem', 'expostul', '8with']
# ['they', 'three', 'stand', 'knot', 'front', 'altar']
# ['i', 'loung', 'side', 'aisl', 'like', 'idler', 'drop', 'church']
# ['suddenli', 'surpris', 'three', 'altar', 'face', 'round', 'godfrey', 'norton', 'came', 'run', 'hard', 'could', 'toward']
# ['thank', 'god', 'cri']
# ['you']
# ['come']
# ['come', 'what', 'i', 'ask']
# ['come', 'man', 'come', 'three', 'minut', 'i', 'altar', 'i', 'knew', 'i', 'i', 'found', 'mumbl', 'spons', 'whisper', 'ear', 'ing', 'thing', 'i', 'knew', 'noth', 'gener', 'assist', 'secur', 'tie', 'iren', 'adler', 'ster', 'godfrey', 'norton', 'bachelor']
# ['it', 'done', 'instant', 'gentleman', 'thank', 'one', 'side', 'ladi', 'clergyman', 'beam', 'front']
# ['it', 'preposter', 'posit', 'i', 'ever', 'found', 'life', 'thought', 'start', 'laugh']
# ['it', 'seem', 'inform', 'licens', 'clergyman', 'absolut', 'refus', 'marri', 'without', 'wit', 'sort', 'lucki', 'appear', 'save', 'bridegroom', 'salli', 'street', 'search', 'best', 'man']
# ['the', 'bride', 'gave', 'sovereign', 'i', 'mean', 'wear', 'memori', 'thi', 'unexpect', 'turn', 'affair', 'said', 'i', 'well', 'i', 'found', 'plan', 'serious', 'menac']
# ['it', 'look', 'pair', 'might', 'take', 'immedi', 'partur', 'necessit', 'prompt', 'energet', 'measur', 'part']
# ['at', 'church', 'door', 'howev', 'separ', 'drive', 'back', 'templ', 'hous']
# ['i', 'shall', 'drive', 'park', 'ﬁve', 'usual', 'said', 'left']
# ['i', 'heard']
# ['they', 'drove', 'away', 'differ', 'direct', 'i', 'went', 'make', 'which', 'some', 'cold', 'beef', 'glass', 'beer', 'answer', 'ring', 'bell']
# ['i', 'busi', 'think', 'food', 'i', 'like', 'busier', 'still', 'even']
# ['by', 'way', 'doctor', 'i', 'shall', 'want', 'i', 'shall', 'you', 'mind', 'break', 'law', 'not', 'nor', 'run', 'chanc', 'arrest', 'not', 'good', 'oh', 'caus', 'excel', 'then', 'i', 'i', 'sure', 'i', 'might', 'reli', 'but', 'wish', 'when', 'turner', 'brought', 'tray', 'i', 'make', 'clear']
# ['now', 'said', 'turn', 'hungrili', 'simpl', 'fare', 'landladi', 'provid', 'i', 'must', 'discuss', 'i', 'eat', 'i', 'much', 'time']
# ['it', 'nearli', 'ﬁve']
# ['in', 'two', 'hour', 'must', 'scene', 'action']
# ['miss', 'iren', 'madam', 'rather', 'return', 'drive', 'seven']
# ['we', 'must', 'brioni', 'lodg', 'meet', 'and', 'you', 'must', 'leav']
# ['i', 'alreadi', 'rang', 'occur']
# ['there', 'one', 'point', 'i', 'must', 'insist']
# ['you', 'must', 'interfer', 'come', 'may']
# ['you', 'understand', 'i', 'neutral', 'to', 'noth', 'whatev']
# ['there', 'probabl', 'small', 'unpleas']
# ['do', 'join']
# ['it', 'end', 'convey', 'hous']
# ['four', 'ﬁve', 'minut', 'afterward', 'window', 'open']
# ['you', 'station', 'close', 'open', 'you', 'watch', 'i', 'visibl', 'and', 'i', 'rais', 'throw', 'room', 'i', 'give', 'throw', 'time', 'rais', 'cri', 'ﬁre']
# ['you', 'quit', 'follow', 'it', 'noth', 'formid', 'said', 'take', 'long', 'roll', 'pocket']
# ['it', 'ordinari', 'plumber', 'ﬁtted', 'cap', 'either', 'end', 'make']
# ['your', 'task', 'conﬁn']
# ['when', 'rais', 'cri', 'ﬁre', 'taken', 'quit', 'number', 'peopl']
# ['you', 'may', 'walk', 'end', 'street', 'i', 'rejoin', 'ten', 'minut']
# ['i', 'hope', 'i', 'made', 'clear', 'i', 'remain', 'neutral', 'get', 'near', 'window', 'watch', 'signal', 'throw', 'object', 'rais', 'cri', 'ﬁre', 'wait', 'corner', 'then', 'may', 'entir', 'reli', 'that', 'excel']
# ['i', 'think', 'perhap', 'almost', 'time', 'i', 'prepar', 'new', 'role', 'i', '9he', 'disappear', 'bedroom', 'return', 'minut', 'charact', 'amiabl', 'nonconformist', 'clergyman']
# ['hi', 'broad', 'black', 'hat', 'baggi', 'trouser', 'white', 'tie', 'thetic', 'smile', 'gener', 'look', 'peer', 'lent', 'curios', 'john', 'hare', 'alon', 'could', 'equal']
# ['it', 'mere', 'holm', 'chang', 'costum']
# ['hi', 'express', 'manner', 'soul', 'seem', 'vari', 'everi', 'fresh', 'part', 'assum']
# ['the', 'stage', 'lost', 'ﬁne', 'actor', 'even', 'scienc', 'lost', 'acut', 'reason', 'becam', 'specialist', 'crime']
# ['it', 'quarter', 'past', 'six', 'left', 'baker', 'street', 'still', 'want', 'ten', 'minut', 'hour', 'found', 'serpentin', 'avenu']
# ['it', 'alreadi', 'dusk', 'lamp', 'light', 'pace', 'front', 'brioni', 'lodg', 'wait', 'come', 'occup']
# ['the', 'hous', 'i', 'pictur', 'sherlock', 'holm', 'cinct', 'descript', 'local', 'appear', 'less', 'privat', 'i', 'expect']
# ['on', 'contrari', 'small', 'street', 'quiet', 'neighbourhood', 'remark', 'anim']
# ['there', 'group', 'shabbili', 'dress', 'men', 'smoke', 'laugh', 'corner', 'grinder', 'wheel', 'two', 'guardsmen', 'ﬂirt', 'sever', 'young', 'men', 'loung', 'cigar', 'mouth']
# ['you', 'see', 'remark', 'holm', 'pace', 'fro', 'front', 'hous', 'marriag', 'rather', 'pliﬁe', 'matter']
# ['the', 'photograph', 'becom', 'edg', 'weapon']
# ['the', 'chanc', 'would', 'avers', 'seen', 'godfrey', 'ton', 'client', 'come', 'eye', 'princess']
# ['now', 'question', 'ﬁnd', 'photograph', 'where', 'inde', 'it', 'unlik', 'carri']
# ['it', 'cabinet', 'size']
# ['too', 'larg', 'easi', 'conceal', 'woman', 'dress']
# ['she', 'know', 'king', 'capabl', 'waylaid', 'search']
# ['two', 'attempt', 'sort', 'alreadi', 'made']
# ['we', 'may', 'take', 'carri', 'where', 'her', 'banker', 'lawyer']
# ['there', 'ble', 'possibl']
# ['but', 'i', 'inclin', 'think', 'neither']
# ['women', 'natur', 'secret', 'like', 'secret']
# ['whi', 'hand', 'anyon', 'els']
# ['she', 'could', 'trust', 'ship', 'could', 'tell', 'indirect', 'polit', 'inﬂuenc', 'might', 'brought', 'bear', 'upon', 'busi', 'man']
# ['besid', 'rememb', 'resolv', 'use', 'within', 'day']
# ['it', 'must', 'lay', 'hand', 'upon']
# ['it', 'must', 'but', 'twice', 'pshaw']
# ['they', 'know', 'but', 'look', 'i', 'what', 'i', 'get', 'show', 'but', 'she', 'abl']
# ['but', 'i', 'hear', 'rumbl', 'wheel']
# ['it', 'carriag']
# ['now', 'carri', 'order', 'as', 'spoke', 'gleam', 'riag', 'came', 'round', 'curv', 'avenu']
# ['it', 'smart', 'littl', 'landau', 'rattl', 'door', 'brioni', 'lodg']
# ['as', 'pull', 'one', 'loaﬁng', 'men', 'corner', 'dash', 'forward', 'open', 'door', 'hope', 'earn', 'copper', 'elbow', 'away', 'anoth', 'loafer', 'rush', 'intent']
# ['a', 'ﬁerc', 'quarrel', 'broke', 'increas', 'two', 'guardsmen', 'took', 'side', 'one', 'lounger', 'equal', 'hot', 'upon', 'side']
# ['a', 'blow', 'struck', 'instant', 'ladi', 'step', 'carriag', 'centr', 'littl', 'knot', 'ﬂush', 'struggl', 'men', 'struck', 'savag', 'ﬁst', 'stick']
# ['holm', 'dash', 'crowd', 'protect', 'ladi', 'reach', 'gave', 'cri', 'drop', 'ground', 'blood', 'run', 'freeli', 'face']
# ['at', 'fall', 'guardsmen', 'took', 'heel', 'one', 'tion', 'lounger', 'number', 'peopl', 'watch', 'scufﬂ', 'without', 'take', 'part', 'crowd', 'help', 'ladi', 'attend', 'injur', 'man']
# ['iren', 'adler', 'i', 'still', 'call', 'hurri', 'step', 'stood', 'top', 'superb', 'ﬁgure', 'outlin', 'light', 'hall', 'look', 'back', 'street']
# ['is', 'poor', 'gentleman', 'much', 'hurt', 'ask']
# ['he', 'dead', 'cri', 'sever', 'voic']
# ['no', 'life', 'shout', 'anoth']
# ['but', 'gone', 'get', 'he', 'brave', 'fellow', 'said', 'woman']
# ['they', 'would', 'ladi', 'purs', 'watch']
# ['they', 'gang', 'rough', 'one']
# ['ah', 'breath', 'he', 'lie', 'street']
# ['may', 'bring', 'marm', 'sure']
# ['bring']
# ['there', 'comfort', 'sofa']
# ['thi', 'way', 'pleas', '10slowli', 'solemnli', 'born', 'brioni', 'lodg', 'laid', 'princip', 'room', 'i', 'still', 'observ', 'proceed', 'post', 'window']
# ['the', 'lamp', 'lit', 'blind', 'drawn', 'i', 'could', 'see', 'holm', 'lay', 'upon', 'couch']
# ['i', 'know', 'whether', 'seiz', 'compunct', 'moment', 'part', 'play', 'i', 'know', 'i', 'never', 'felt', 'heartili', 'asham', 'life', 'i', 'saw', 'beauti', 'creatur', 'i', 'conspir', 'grace', 'kindli', 'wait', 'upon', 'injur', 'man']
# ['and', 'yet', 'would', 'blackest', 'treacheri', 'holm', 'draw', 'back', 'part', 'intrust']
# ['i', 'harden', 'heart', 'took', 'ulster']
# ['ter', 'i', 'thought', 'injur']
# ['we', 'prevent', 'injur', 'anoth']
# ['holm', 'sat', 'upon', 'couch', 'i', 'saw', 'motion', 'like', 'man', 'need', 'air']
# ['a', 'maid', 'rush', 'across', 'threw', 'open', 'window']
# ['at', 'instant', 'i', 'saw', 'rais', 'hand', 'nal', 'i', 'toss', 'rocket', 'room', 'cri', 'fire', 'the', 'word', 'sooner', 'mouth', 'whole', 'crowd', 'spectat', 'well', 'dress', 'ostler', 'gener', 'shriek', 'fire', 'thick', 'cloud', 'smoke', 'curl', 'room', 'open', 'window']
# ['i', 'caught', 'glimps', 'rush', 'ﬁgure', 'moment', 'later', 'voic', 'holm', 'within', 'assur', 'fals', 'alarm']
# ['slip', 'ing', 'crowd', 'i', 'made', 'way', 'corner', 'street', 'ten', 'minut', 'rejoic', 'ﬁnd', 'friend', 'arm', 'mine', 'get', 'away', 'scene', 'roar']
# ['he', 'walk', 'swiftli', 'silenc', 'minut', 'turn', 'one', 'quiet', 'street', 'lead', 'toward', 'edgewar', 'road']
# ['you', 'nice', 'doctor', 'remark']
# ['noth', 'could', 'better']
# ['it', 'you', 'photograph', 'i', 'know', 'and', 'ﬁnd', 'she', 'show', 'i', 'told', 'i', 'still', 'i', 'wish', 'make', 'mysteri', 'said', 'ing']
# ['the', 'matter', 'perfectli', 'simpl']
# ['you', 'cours', 'saw', 'everyon', 'street', 'accomplic']
# ['they', 'engag', 'i', 'guess', 'then', 'row', 'broke', 'i', 'littl', 'moist', 'red', 'paint', 'palm', 'hand']
# ['i', 'rush', 'forward', 'fell', 'clap', 'hand', 'face', 'becam', 'piteou', 'spectacl']
# ['it', 'old', 'that', 'also', 'i', 'could', 'then', 'carri']
# ['she', 'bound']
# ['what', 'els', 'could']
# ['and', 'room', 'room', 'i', 'suspect']
# ['it', 'lay', 'bedroom', 'i', 'termin', 'see']
# ['they', 'laid', 'couch', 'i', 'motion', 'air', 'compel', 'open', 'window', 'how', 'help', 'it']
# ['when', 'woman', 'think', 'hous', 'ﬁre', 'instinct', 'rush', 'thing', 'valu']
# ['it', 'perfectli', 'overpow', 'impuls', 'i', 'taken', 'advantag']
# ['in', 'case', 'darlington', 'substitut', 'scandal', 'use', 'also', 'arnsworth', 'castl', 'busi']
# ['a', 'marri', 'woman', 'grab', 'babi', 'unmarri', 'one', 'reach']
# ['now', 'clear', 'ladi', 'noth', 'hous', 'preciou', 'quest']
# ['she', 'would', 'rush', 'secur']
# ['the', 'alarm', 'ﬁre', 'admir', 'done']
# ['the', 'smoke', 'shout', 'enough', 'shake', 'nerv', 'steel']
# ['she', 'respond', 'beauti']
# ['the', 'photograph', 'recess', 'behind', 'slide', 'panel', 'right']
# ['she', 'instant', 'i', 'caught', 'glimps']
# ['when', 'i', 'cri', 'fals', 'alarm', 'replac', 'glanc', 'rocket', 'rush', 'room', 'i', 'seen', 'sinc']
# ['i', 'rose', 'make', 'excus', 'cape', 'hous']
# ['i', 'hesit', 'whether', 'attempt', 'secur', 'photograph', 'coachman', 'come', 'watch', 'narrowli', 'seem', 'safer', 'wait']
# ['a', 'littl', 'may', 'ruin', 'and', 'i', 'ask']
# ['our', 'quest', 'practic', 'ﬁnish']
# ['i', 'shall', 'call', 'king', 'care', 'come', 'us']
# ['we', 'shown', 'wait', 'ladi', 'probabl', 'come', 'may', 'ﬁnd', 'neither', 'us', 'photograph']
# ['it', 'might', 'satisfact', 'majesti', 'regain', 'and', 'call', 'at', 'eight', 'morn']
# ['she', 'shall', 'clear', 'ﬁeld']
# ['besid', 'must', 'prompt', 'marriag', 'may', 'mean', 'complet', 'chang', 'life', 'habit']
# ['i', 'must', 'wire', 'king', 'without', '11we', 'reach', 'baker', 'street', 'stop', 'door']
# ['he', 'search', 'pocket', 'key', 'someon', 'pass', 'said', 'mister', 'sherlock', 'there', 'sever', 'peopl', 'pavement', 'time', 'greet', 'appear', 'come', 'slim', 'youth', 'ulster', 'hurri']
# ['i', 'heard', 'voic', 'said', 'holm', 'ing', 'dimli', 'lit', 'street']
# ['now', 'i', 'wonder', 'deuc', 'could', 'chapter', 'iii']
# ['i', 'slept', 'baker', 'street', 'night', 'engag', 'upon', 'toast', 'coffe', 'morn', 'king', 'bohemia', 'rush', 'room']
# ['you', 'realli', 'got', 'cri', 'grasp', 'lock', 'holm', 'either', 'shoulder', 'look', 'eagerli', 'face']
# ['not', 'but', 'hope', 'i', 'then', 'come']
# ['i', 'impati', 'we', 'must', 'no', 'brougham', 'then', 'simplifi', 'we', 'descend', 'start', 'brioni', 'lodg']
# ['iren', 'adler', 'marri', 'remark', 'holm']
# ['marri']
# ['when', 'but', 'to', 'english', 'lawyer', 'name', 'but', 'could', 'love', 'i', 'hope', 'and', 'hope', 'becaus', 'would', 'spare', 'majesti', 'fear', 'futur', 'annoy']
# ['if', 'ladi', 'love', 'husband', 'love', 'majesti']
# ['if', 'love', 'majesti', 'reason', 'interfer', 'majesti', 'it', 'true']
# ['and']
# ['i', 'wish', 'station']
# ['what', 'queen', 'would', 'made', 'he', 'relaps', 'moodi', 'silenc', 'broken', 'drew', 'serpentin', 'avenu']
# ['the', 'door', 'brioni', 'lodg', 'open', 'derli', 'woman', 'stood', 'upon', 'step']
# ['she', 'watch', 'us', 'sardon', 'eye', 'step', 'brougham']
# ['mr']
# ['sherlock', 'holm', 'i', 'believ', 'said']
# ['i', 'holm', 'answer', 'companion', 'look', 'question', 'rather', 'startl', 'gaze']
# ['inde']
# ['my', 'mistress', 'told', 'like', 'call']
# ['she', 'left', 'morn', 'husband', 'train', 'chare', 'cross', 'what', 'sherlock', 'holm', 'stagger', 'back', 'white', 'chagrin', 'surpris']
# ['do', 'mean', 'left', 'england', 'never', 'and', 'paper', 'ask', 'king', 'hoars']
# ['all', 'we', 'shall', 'he', 'push', 'past', 'servant', 'rush', 'follow', 'king']
# ['the', 'furnitur', 'scatter', 'everi', 'direct', 'dismantl', 'shelv', 'open', 'drawer', 'ladi', 'hurriedli', 'ransack', 'ﬂight']
# ['holm', 'rush', 'tore', 'back', 'small', 'slide', 'shutter', 'plung', 'hand', 'pull', 'photograph', 'letter']
# ['the', 'tograph', 'iren', 'adler', 'even', 'dress', 'letter', 'superscrib', 'sherlock', 'holm', 'esq']
# ['to', 'left', 'till', 'call', 'my', 'friend', 'tore', 'open', 'three', 'read', 'togeth']
# ['it', 'date', 'midnight', 'preced', 'night', 'ran', 'way', '12', 'my', 'dearmr']
# ['sherlock', 'holm', 'you', 'realli', 'well']
# ['you', 'took', 'complet']
# ['until', 'alarm', 'ﬁre', 'i', 'suspicion']
# ['but', 'i', 'found', 'i', 'betray', 'i', 'gan', 'think']
# ['i', 'warn', 'month', 'ago']
# ['i', 'told', 'king', 'employ', 'agent', 'would', 'certainli']
# ['and', 'address', 'given']
# ['yet', 'made', 'reveal', 'want', 'know']
# ['even', 'i', 'came', 'suspici', 'i', 'found', 'hard', 'think', 'evil', 'dear', 'kind', 'old', 'clergyman']
# ['but', 'know', 'i', 'train', 'actress']
# ['male', 'costum', 'noth', 'new']
# ['i', 'often', 'take', 'advantag', 'freedom', 'give']
# ['i', 'sent', 'john', 'coachman', 'watch', 'ran', 'stair', 'got', 'i', 'call', 'came', 'depart']
# ['well', 'i', 'follow', 'door', 'made', 'sure', 'i', 'realli', 'ject', 'interest', 'celebr', 'lock', 'holm']
# ['then', 'i', 'rather', 'imprud', 'wish', 'start', 'templ', 'see', 'husband']
# ['we', 'thought', 'best', 'resourc', 'ﬂight', 'pursu', 'formid', 'antagonist', 'ﬁnd', 'nest', 'empti', 'call']
# ['as', 'tograph', 'client', 'may', 'rest', 'peac']
# ['i', 'love', 'love', 'better', 'man']
# ['the', 'king', 'may', 'without', 'hindranc', 'one', 'cruelli', 'wrong']
# ['i', 'keep', 'safeguard', 'self', 'preserv', 'weapon', 'alway', 'secur', 'step', 'might', 'take', 'futur']
# ['i', 'leav', 'tograph', 'might', 'care', 'possess', 'i', 'remain', 'dear', 'sherlock', 'holm', 'veri', 'truli', 'iren', 'norton', 'what', 'woman', 'cri', 'king', 'bohemia', 'three', 'read', 'epistl']
# ['did', 'i', 'tell', 'quick', 'resolut']
# ['would', 'made', 'admir', 'queen']
# ['is', 'piti', 'level', 'from', 'i', 'seen', 'ladi', 'seem', 'inde', 'differ', 'level', 'majesti', 'said', 'holm', 'coldli']
# ['i', 'sorri', 'i', 'abl', 'bring', 'majesti', 'busi', 'cess', 'on', 'contrari', 'dear', 'sir', 'cri', 'king', 'noth', 'could', 'success']
# ['i', 'know', 'word', 'inviol']
# ['the', 'photograph', 'safe', 'i', 'glad', 'hear', 'majesti', 'say', 'i', 'immens', 'indebt']
# ['pray', 'tell', 'way', 'i', 'reward']
# ['thi', 'he', 'slip', 'emerald', 'snake', 'ring', 'ﬁnger', 'held', 'upon', 'palm', 'hand']
# ['your', 'majesti', 'someth', 'i', 'valu', 'even', 'highli', 'said', 'holm']
# ['you', 'name', 'thi', 'photograph', 'the', 'king', 'stare', 'amaz']
# ['iren', 'photograph', 'cri']
# ['certainli', 'wish', 'i', 'thank', 'majesti']
# ['then', 'done', 'matter']
# ['i', 'honour', 'wish', 'he', 'bow', 'turn', 'away', 'without', 'observ', 'hand', 'king', 'stretch', 'set', 'compani', 'chamber']
# ['and', 'great', 'scandal', 'threaten', 'fect', 'kingdom', 'bohemia', 'best', 'plan', 'sherlock', 'holm', 'beaten', 'woman', 'wit']
# ['he', 'use', 'make', 'merri', 'clever', 'women', 'i', 'heard', 'late']
# ['and', 'speak', 'iren', 'adler', 'refer', 'photograph', 'alway', 'honour', 'titl', 'woman']
# ['13']
# My own complete
# happiness, and the home-centred interests which rise
# up around the man who ﬁrst ﬁnds himself master of
# his own establishment, were sufﬁcient to absorb all
# my attention, while Holmes, who loathed every form
# of society with his whole Bohemian soul, remained
# in our lodgings in Baker Street, buried among his old
# books, and alternating from week to week between
# cocaine and ambition, the drowsiness of the drug,
# and the ﬁerce energy of his own keen nature. As to your practice, if a gentleman
# walks into my rooms smelling of iodoform, with a
# black mark of nitrate of silver upon his right foreﬁn-
# ger, and a bulge on the right side of his top-hat to
# show where he has secreted his stethoscope, I must
# be dull, indeed, if I do not pronounce him to be an
# active member of the medical profession.”
# I could not help laughing at the ease with which
# he explained his process of deduction. I lent the ostlers
# a hand in rubbing down their horses, and received
# in exchange twopence, a glass of half and half, two
# ﬁlls of shag tobacco, and as much information as I
# could desire about Miss Adler, to say nothing of half a
# dozen other people in the neighbourhood in whom I
# was not in the least interested, but whose biographies
# I was compelled to listen to.”
# “And what of Irene Adler?” I asked. By the way, Doctor, I shall want your co-operation.”
# “I shall be delighted.”
# “You don’t mind breaking the law?”
# “Not in the least.”
# “Nor running a chance of arrest?”
# “Not in a good cause.”
# “Oh, the cause is excellent!”
# “Then I am your man.”
# “I was sure that I might rely on you.”
# “But what is it you wish?”
# “When Mrs. Turner has brought in the tray I will
# make it clear to you. At the
# same instant I saw him raise his hand and at the sig-
# nal I tossed my rocket into the room with a cry of
# “Fire!” The word was no sooner out of my mouth
# than the whole crowd of spectators, well dressed and
# ill—gentlemen, ostlers, and servant-maids—joined
# in a general shriek of “Fire!” Thick clouds of smoke
# curled through the room and out at the open window.
